# %%
list_kosong = []

# %%
list_buah = ["Pisang", "Nanas", "Melon", "Durian"]

# %%
list_angka = [100, 200, 1000, 2000]

# %%
list_campur = ["Nasi", 200, 1000, 5000, "Ikan", True]

# %%
print ('list_kosong', list_kosong)
# Out:
# list_kosong []

# %%
print ('list_buah', list_buah)
# Out:
# list_buah ['Pisang', 'Nanas', 'Melon', 'Durian']

# %%
print ('list angka', list_angka)
# Out:
# list angka [100, 200, 1000, 2000]

# %%
print ('list campur', list_campur)
# Out:
# list campur ['Nasi', 200, 1000, 5000, 'Ikan', True]

# %%
print(list_buah[0])
# Out:
# Pisang

# %%
print(list_buah[1])
# Out:
# Nanas

# %%
print(list_buah[2])
# Out:
# Melon

# %%
print(list_buah[3])
# Out:
# Durian

# %%
print(list_buah[0:1])
# Out:
# ['Pisang']

# %%
print(list_buah[1:3])
# Out:
# ['Nanas', 'Melon']

# %%
print(list_buah[3:4])
# Out:
# ['Durian']

# %%
print(list_buah)
# Out:
# ['Pisang', 'Nanas', 'Melon', 'Durian']

# %%
list_buah.append("Sirsak")

# %%
a = [1, 2, 3]
b = ["a"]
c = [True, "b", False]

# %%
listbaru = a+b+c

# %%
print(listbaru)
# Out:
# [1, 2, 3, 'a', True, 'b', False]

# %%
print(list_buah)
# Out:
# ['Pisang', 'Nanas', 'Melon', 'Durian', 'Sirsak']

# %%
list_buah.sort()
print(list_buah)
# Out:
# ['Durian', 'Melon', 'Nanas', 'Pisang', 'Sirsak']

# %%
list_buah.reverse()
print(list_buah)
# Out:
# ['Durian', 'Melon', 'Nanas', 'Pisang', 'Sirsak']

# %%
list_angka
# Out:
# [100, 200, 1000, 2000]

# %%
list_angka.reverse()
print(list_angka)
# Out:
# [2000, 1000, 200, 100]

# %%
list_angka.sort()
print(list_angka)
# Out:
# [100, 200, 1000, 2000]

# %%
list_angka.reverse()
print(list_angka)
# Out:
# [2000, 1000, 200, 100]

# %%
list_buah
# Out:
# ['Durian', 'Melon', 'Nanas', 'Pisang', 'Sirsak']

# %%
list_buah.clear()
print(list_buah)
# Out:
# []
